# %%
import random
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import io
import requests
import math
from scipy.stats import norm
from random import randint
from scipy.stats import binom
import statistics
import pandas as pd

# %%
indoor_data = pd.read_csv('basement_data.csv')

# %%
indoor_data
# Out:
#      Time (Unix)  Temperatures(Celsius)  Pressure(Hectopascals)   Humidity  \
# 0     1630754285              21.812109             1004.349932  49.257930
# 1     1630754286              21.852539             1004.345056  49.298878
# 2     1630754287              21.822266             1004.357028  49.212404
# 3     1630754288              21.827344             1004.366560  49.315545
# 4     1630754289              21.817187             1004.348511  49.154998
# ..           ...                    ...                     ...        ...
# 284   1630754577              21.969141             1004.245477  48.590470
# 285   1630754578              21.969141             1004.229249  48.601936
# 286   1630754579              21.964063             1004.227428  48.728257
# 287   1630754580              21.969141             1004.252167  48.756724
# 288   1630754581              21.979297             1004.220937  48.831349
#
#      pm1  pm2.5  pm10
# 0      0      2     3
# ...

# %%
#Graphing Temperature Data
plt.plot(indoor_data["Temperatures(Celsius)"])
plt.ylabel('Temperature (Celsius)')            
plt.xlabel('Device Time')
plt.title("Temperatures (Celsius) Vs. Device Time")    
plt.show()

plt.hist(indoor_data["Temperatures(Celsius)"], bins = 40)
plt.xlabel('Temperature (Celsius)')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Temperatures (Celsius)")    

def indoor_Gaus_distribution(x , mean , sd):
    Px = (288*(3.14*sd) * np.exp(-0.5*((x-mean)/sd)**2))
    return Px

temp_mu = np.mean(indoor_data["Temperatures(Celsius)"])
temp_std = np.std(indoor_data["Temperatures(Celsius)"])

x = np.linspace(np.min(indoor_data["Temperatures(Celsius)"]), np.max(indoor_data["Temperatures(Celsius)"]), 150)

Temp_gauss = indoor_Gaus_distribution(x,temp_mu,temp_std)

plt.plot(x, Temp_gauss, color = 'red')
plt.xlabel('Temperatures (celsius)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.plot(indoor_data["Pressure(Hectopascals)"])
plt.ylabel('Pressure (HectoPascals)')            
plt.xlabel('Device Time')
plt.title("Pressure (HectoPascals) Vs. Device Time")                             
plt.show()

plt.hist(indoor_data["Pressure(Hectopascals)"], bins = 25)
plt.xlabel('Pressure (HectoPascals)')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Pressure (HectoPascals)")                             

press_mu = np.mean(indoor_data["Pressure(Hectopascals)"])
press_std = np.std(indoor_data["Pressure(Hectopascals)"])

x = np.linspace(np.min(indoor_data["Pressure(Hectopascals)"]), np.max(indoor_data["Pressure(Hectopascals)"]), 150)

press_gauss = indoor_Gaus_distribution(x,press_mu,press_std)

plt.plot(x, press_gauss, color = 'red')
plt.show()

# %%
plt.plot(indoor_data["Humidity"])
plt.ylabel('Humidity')            
plt.xlabel('Device Time')
plt.title("Humidity Vs. Device Time")                             
plt.show()

plt.hist(indoor_data["Humidity"], bins = 25)
plt.xlabel('Humidity')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Humidity")    

humid_mu = np.mean(indoor_data["Humidity"])
humid_std = np.std(indoor_data["Humidity"])

x = np.linspace(np.min(indoor_data["Humidity"]), np.max(indoor_data["Humidity"]), 150)

humid_gauss = indoor_Gaus_distribution(x,humid_mu,humid_std)

plt.plot(x, humid_gauss, color = 'red')

plt.show()

# %%
plt.plot(indoor_data["pm1"])
plt.ylabel('PM1')            
plt.xlabel('Device Time')
plt.title("Pm1 Vs. Device Time")                             
plt.show()

plt.hist(indoor_data["pm2.5"])
plt.xlabel('PM1')            
plt.ylabel('Frequency')
plt.title("Frequency Vs Pm1")    

pm1_mu = np.mean(indoor_data["pm1"])
pm1_std = np.std(indoor_data["pm1"])

x = np.linspace(np.min(indoor_data["pm1"]), np.max(indoor_data["pm1"]), 150)

pm1_gauss = indoor_Gaus_distribution(x,pm1_mu,pm1_std)

plt.plot(x, pm1_gauss, color = 'red')

plt.show()
# Out:
# <ipython-input-4-814ae61df7d7>:14: RuntimeWarning: invalid value encountered in true_divide
#   Px = (288*(3.14*sd) * np.exp(-0.5*((x-mean)/sd)**2))

# %% [markdown]
# PM1 Normal Distribution cannot be calculated because all values are zero, and thus standard dev is 0 but you cannot divide by 0

# %%
plt.plot(indoor_data["pm2.5"])
plt.ylabel('PM1')            
plt.xlabel('Device Time')
plt.title("Pm1 Vs. Device Time")                             
plt.show()

plt.hist(indoor_data["pm2.5"])
plt.xlabel('PM2.5')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Pm2.5")        

pm25_mu = np.mean(indoor_data["pm2.5"])
pm25_std = np.std(indoor_data["pm2.5"])

x = np.linspace(np.min(indoor_data["pm2.5"]), np.max(indoor_data["pm2.5"]), 150)

pm25_gauss = indoor_Gaus_distribution(x,pm25_mu,pm25_std)

plt.plot(x, pm25_gauss, color = 'red')
plt.show()

# %%
plt.plot(indoor_data["pm10"])
plt.ylabel('PM1')            
plt.xlabel('Device Time')
plt.title("Pm1 Vs. Device Time")                             
plt.show()

plt.hist(indoor_data["pm10"])
plt.xlabel('PM10')            
plt.ylabel('Frequency')
plt.title("Pm10 Vs. Device Time")     

pm10_mu = np.mean(indoor_data["pm10"])
pm10_std = np.std(indoor_data["pm10"])

x = np.linspace(np.min(indoor_data["pm10"]), np.max(indoor_data["pm10"]), 150)

pm10_gauss = indoor_Gaus_distribution(x,pm10_mu,pm10_std)

plt.plot(x, pm10_gauss, color = 'red')
plt.show()

# %%
outdoor_data = pd.read_csv('outdoor_data.csv')

# %%
outdoor_data
# Out:
#      Time (Unix)  Temperatures(Celsius)  Pressure(Hectopascals)   Humidity  \
# 0     1633054306              23.738086             1002.165802  29.107554
# 1     1633054307              23.748242             1002.203954  29.170973
# 2     1633054308              23.743164             1002.162837  29.032300
# 3     1633054309              23.743164             1002.170973  29.211366
# 4     1633054310              23.738086             1002.200410  29.101766
# ..           ...                    ...                     ...        ...
# 288   1633054602              22.851172             1002.164357  29.442017
# 289   1633054603              22.835938             1002.175079  29.615675
# 290   1633054604              22.825781             1002.184984  29.679453
# 291   1633054605              22.820703             1002.170195  29.690763
# 292   1633054606              22.810547             1002.207569  29.546483
#
#      pm1  pm2.5  pm10
# 0      0      0     0
# ...

# %%
#Graphing Temperature Data
plt.plot(outdoor_data["Temperatures(Celsius)"])
plt.ylabel('Temperature (Celsius)')            
plt.xlabel('Device Time')
plt.title("Temperatures (Celsius) Vs. Device Time")    
plt.show()

plt.hist(outdoor_data["Temperatures(Celsius)"], bins = 20)
plt.xlabel('Temperature (Celsius)')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Temperatures (Celsius)")    

def outdoor_Gaus_distribution(x , mean , sd):
    Px = (292*(3.14*sd) * np.exp(-0.5*((x-mean)/sd)**2))
    return Px

outdoor_temp_mu = np.mean(outdoor_data["Temperatures(Celsius)"])
outdoor_temp_std = np.std(outdoor_data["Temperatures(Celsius)"])

x = np.linspace(np.min(outdoor_data["Temperatures(Celsius)"]), np.max(outdoor_data["Temperatures(Celsius)"]), 150)

Outdoor_Temp_gauss = outdoor_Gaus_distribution(x,outdoor_temp_mu,outdoor_temp_std)

plt.plot(x, Outdoor_Temp_gauss, color = 'red')
plt.xlabel('Temperatures (celsius)')
plt.ylabel('Frequency')
plt.show()

# %%
#Graphing Temperature Data
plt.plot(outdoor_data["Pressure(Hectopascals)"])
plt.ylabel('Pressure(Hectopascals)')            
plt.xlabel('Device Time')
plt.title("Pressure(Hectopascals) Vs. Device Time")    
plt.show()

plt.hist(outdoor_data["Pressure(Hectopascals)"], bins = 20)
plt.xlabel('Pressure(Hectopascals)')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Pressure(Hectopascals)")    

outdoor_press_mu = np.mean(outdoor_data["Pressure(Hectopascals)"])
outdoor_press_std = np.std(outdoor_data["Pressure(Hectopascals)"])

x = np.linspace(np.min(outdoor_data["Pressure(Hectopascals)"]), np.max(outdoor_data["Pressure(Hectopascals)"]), 150)

Outdoor_Press_gauss = outdoor_Gaus_distribution(x,outdoor_press_mu,outdoor_press_std)

plt.plot(x, Outdoor_Press_gauss, color = 'red')
plt.xlabel('Pressure(Hectopascals)')
plt.ylabel('Frequency')
plt.show()

# %%
#Graphing Temperature Data
plt.plot(outdoor_data["Humidity"])
plt.ylabel('Humidity')            
plt.xlabel('Device Time')
plt.title("Humidity Vs. Device Time")    
plt.show()

plt.hist(outdoor_data["Humidity"], bins = 20)
plt.xlabel('Humidity')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. Humidity")    

outdoor_humid_mu = np.mean(outdoor_data["Humidity"])
outdoor_humid_std = np.std(outdoor_data["Humidity"])

x = np.linspace(np.min(outdoor_data["Humidity"]), np.max(outdoor_data["Humidity"]), 150)

Outdoor_Humid_gauss = outdoor_Gaus_distribution(x,outdoor_humid_mu,outdoor_humid_std)

plt.plot(x, Outdoor_Humid_gauss, color = 'red')
plt.xlabel('Humidity')
plt.ylabel('Frequency')
plt.show()

# %%
#Graphing Temperature Data
plt.plot(outdoor_data["pm1"])
plt.ylabel('PM1')            
plt.xlabel('Device Time')
plt.title("PM1 Vs. Device Time")    
plt.show()

plt.hist(outdoor_data["pm1"], bins = 20)
plt.xlabel('PM1')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. PM1")    

outdoor_pm1_mu = np.mean(outdoor_data["pm1"])
outdoor_pm1_std = np.std(outdoor_data["pm1"])

x = np.linspace(np.min(outdoor_data["pm1"]), np.max(outdoor_data["pm1"]), 150)

Outdoor_pm1_gauss = outdoor_Gaus_distribution(x,outdoor_pm1_mu,outdoor_pm1_std)

plt.plot(x, Outdoor_pm1_gauss, color = 'red')
plt.xlabel('PM1')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-12-c52fa792cf74>:14: RuntimeWarning: invalid value encountered in true_divide
#   Px = (292*(3.14*sd) * np.exp(-0.5*((x-mean)/sd)**2))

# %% [markdown]
# PM1 Normal Distribution cannot be calculated because all values are zero, and thus standard dev is 0 but you cannot divide by 0

# %%
#Graphing Temperature Data
plt.plot(outdoor_data["pm2.5"])
plt.ylabel('PM2.5')            
plt.xlabel('Device Time')
plt.title("PM2.5 Vs. Device Time")    
plt.show()

plt.hist(outdoor_data["pm2.5"], bins = 20)
plt.xlabel('PM2.5')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. PM2.5")    

outdoor_pm25_mu = np.mean(outdoor_data["pm2.5"])
outdoor_pm25_std = np.std(outdoor_data["pm2.5"])

x = np.linspace(np.min(outdoor_data["pm2.5"]), np.max(outdoor_data["pm2.5"]), 150)

Outdoor_pm25_gauss = outdoor_Gaus_distribution(x,outdoor_pm25_mu,outdoor_pm25_std)

plt.plot(x, Outdoor_pm25_gauss, color = 'red')
plt.xlabel('PM2.5')
plt.ylabel('Frequency')
plt.show()

# %%
#Graphing Temperature Data
plt.plot(outdoor_data["pm10"])
plt.ylabel('PM10')            
plt.xlabel('Device Time')
plt.title("PM10 Vs. Device Time")    
plt.show()

plt.hist(outdoor_data["pm10"], bins = 20)
plt.xlabel('PM10')            
plt.ylabel('Frequency')
plt.title("Frequency Vs. PM10")    

outdoor_pm10_mu = np.mean(outdoor_data["pm10"])
outdoor_pm10_std = np.std(outdoor_data["pm10"])

x = np.linspace(np.min(outdoor_data["pm10"]), np.max(outdoor_data["pm10"]), 150)

Outdoor_pm10_gauss = outdoor_Gaus_distribution(x,outdoor_pm10_mu,outdoor_pm10_std)

plt.plot(x, Outdoor_pm10_gauss, color = 'red')
plt.xlabel('PM10')
plt.ylabel('Frequency')
plt.show()

# %%
f,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.set_xlim(np.min(indoor_data["Temperatures(Celsius)"]),np.max(indoor_data["Temperatures(Celsius)"]))
ax2.set_xlim(np.min(outdoor_data["Temperatures(Celsius)"]),np.max(outdoor_data["Temperatures(Celsius)"]))

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labelright='off')
ax2.yaxis.tick_right()

ax.hist(indoor_data["Temperatures(Celsius)"], bins = 25)                           

press_mu = np.mean(indoor_data["Temperatures(Celsius)"])
press_std = np.std(indoor_data["Temperatures(Celsius)"])

x = np.linspace(np.min(indoor_data["Temperatures(Celsius)"]), np.max(indoor_data["Temperatures(Celsius)"]), 150)

temp_gauss = indoor_Gaus_distribution(x,temp_mu,temp_std)

ax.plot(x, press_gauss, color = 'blue')

ax2.hist(outdoor_data["Temperatures(Celsius)"], bins = 20, color = 'orange')  

outdoor_temp_mu = np.mean(outdoor_data["Temperatures(Celsius)"])
outdoor_temp_std = np.std(outdoor_data["Temperatures(Celsius)"])

x = np.linspace(np.min(outdoor_data["Temperatures(Celsius)"]), np.max(outdoor_data["Temperatures(Celsius)"]), 150)

Outdoor_Press_gauss = outdoor_Gaus_distribution(x,outdoor_temp_mu,outdoor_temp_std)

ax2.plot(x, Outdoor_Press_gauss, color = 'k')
plt.title("Indoor Temperature vs Outdoor Temperature")
ax.legend(['Indoor Temperature'])
ax2.legend(['Outdoor Temperature'])
plt.show()

# %%
f,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.set_xlim(np.min(indoor_data["Pressure(Hectopascals)"]),np.max(indoor_data["Pressure(Hectopascals)"]))
ax2.set_xlim(np.min(outdoor_data["Pressure(Hectopascals)"]),np.max(outdoor_data["Pressure(Hectopascals)"]))

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labelright='off')
ax2.yaxis.tick_right()

ax.hist(indoor_data["Pressure(Hectopascals)"], bins = 25)                           

press_mu = np.mean(indoor_data["Pressure(Hectopascals)"])
press_std = np.std(indoor_data["Pressure(Hectopascals)"])

x = np.linspace(np.min(indoor_data["Pressure(Hectopascals)"]), np.max(indoor_data["Pressure(Hectopascals)"]), 150)

press_gauss = indoor_Gaus_distribution(x,press_mu,press_std)

ax.plot(x, press_gauss, color = 'blue')

ax2.hist(outdoor_data["Pressure(Hectopascals)"], bins = 20, color = 'orange')  

outdoor_press_mu = np.mean(outdoor_data["Pressure(Hectopascals)"])
outdoor_press_std = np.std(outdoor_data["Pressure(Hectopascals)"])

x = np.linspace(np.min(outdoor_data["Pressure(Hectopascals)"]), np.max(outdoor_data["Pressure(Hectopascals)"]), 150)

Outdoor_Press_gauss = outdoor_Gaus_distribution(x,outdoor_press_mu,outdoor_press_std)

ax2.plot(x, Outdoor_Press_gauss, color = 'k')
plt.title("Indoor Pressure vs Outdoor Pressure")
ax.legend(['Indoor Pressure'])
ax2.legend(['Outdoor Pressure'])
plt.show()

# %%
f,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.set_xlim(np.min(indoor_data["Humidity"]),np.max(indoor_data["Humidity"]))
ax2.set_xlim(np.min(outdoor_data["Humidity"]),np.max(outdoor_data["Humidity"]))

# hide the spines between ax and ax2
ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labelright='off')
ax2.yaxis.tick_right()

ax.hist(indoor_data["Humidity"], bins = 25)                           

press_mu = np.mean(indoor_data["Humidity"])
press_std = np.std(indoor_data["Humidity"])

x = np.linspace(np.min(indoor_data["Humidity"]), np.max(indoor_data["Humidity"]), 150)

press_gauss = indoor_Gaus_distribution(x,press_mu,press_std)

ax.plot(x, press_gauss, color = 'blue')

ax2.hist(outdoor_data["Humidity"], bins = 20, color = 'orange')  

outdoor_press_mu = np.mean(outdoor_data["Humidity"])
outdoor_press_std = np.std(outdoor_data["Humidity"])

x = np.linspace(np.min(outdoor_data["Humidity"]), np.max(outdoor_data["Humidity"]), 150)

Outdoor_Press_gauss = outdoor_Gaus_distribution(x,outdoor_press_mu,outdoor_press_std)

ax2.plot(x, Outdoor_Press_gauss, color = 'k')
plt.title("Indoor Humidity vs Outdoor Humidity")
ax.legend(['Indoor Humidity'])
ax2.legend(['Outdoor Humidity'])
plt.show()
